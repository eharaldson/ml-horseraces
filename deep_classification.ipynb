# %%
import pandas as pd 
import numpy as np 
import torch
import torch
import torch.nn as nn
import torch.optim as optim
import random
from modelling_functions import split_train_validation_data, average_log_loss_score, get_sklearn_model_results_for_races, betting_results_threshold_method, betting_results_top_bsp_method

# %%
df = pd.read_csv('ProcessedDatasetExtra.csv', index_col=0)

# %%
# Split train and validation data
train_data, validation_data = split_train_validation_data(df, validation_split=0.1)

# %%
# Get feature, target and extra information columns from the dataset
info_columns = [
    'DateTime',
    'Track Name',
    'PlaceInt',
    'First Trading Price',
    '15 mins',
    '10 mins',
    '5 mins',
    '3 mins',
    '2 mins',
    '1 min ',
    'Post Time',
    'industry_implied_prob',
    'betfair_implied_prob',
    'industry_implied_prob_norm',
    'betfair_implied_prob_norm'
]

info_columns_set = set(info_columns)

target_column = 'win'

info_columns_set.add(target_column)

feature_columns = list(set(train_data.columns).difference(info_columns_set))

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(train_data[feature_columns])
# Out:
# StandardScaler()

# %%
class LogisticRegression(nn.Module):
    def __init__(self, in_features):
        super().__init__()
        self.lin1 = nn.Linear(in_features, 1)

    def forward(self, H):
        x = self.lin1(H)
        return x
    
class Classification(nn.Module):
    def __init__(self, in_features, hidden_dim):
        super().__init__()
        self.lin1 = nn.Linear(in_features, hidden_dim)
        self.relu = nn.ReLU()
        self.lin2 = nn.Linear(hidden_dim, 1)

    def forward(self, H):
        x = self.lin1(H)
        x = self.relu(x)
        x = self.lin2(x)
        return x
    
class DeepClassification(nn.Module):
    def __init__(self, in_features, hidden_dim1, hidden_dim2, dropout):
        super().__init__()
        self.lin1 = nn.Linear(in_features, hidden_dim1)
        self.dropout = nn.Dropout(dropout)
        self.relu1 = nn.ReLU()
        self.lin2 = nn.Linear(hidden_dim1, hidden_dim2)
        self.relu2 = nn.ReLU()
        self.lin3 = nn.Linear(hidden_dim2, 1)

    def forward(self, H):
        x = self.lin1(H)
        x = self.dropout(x)
        x = self.relu1(x)
        x = self.lin2(x)
        x = self.relu2(x)
        x = self.lin3(x)
        return x

# %%
X_train = train_data[feature_columns].astype(np.float32)
X_train = np.array(scaler.transform(X_train))

y_train = train_data[target_column]

X_train = torch.tensor(X_train)
y_train = torch.tensor(y_train.astype(np.float32).to_numpy())

X_validation = validation_data[feature_columns].astype(np.float32)
X_validation = np.array(scaler.transform(X_validation))

y_validation = validation_data[target_column]

X_validation = torch.tensor(X_validation)
y_validation = torch.tensor(y_validation.astype(np.float32).to_numpy())

# %%
from torch.utils.data import DataLoader, TensorDataset

batch_size = 32
validation_fraction = 0.1
validation_index = round(len(y)*(1-validation_fraction))

train_dataset = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

validation_dataset = TensorDataset(X_validation, y_validation)
validation_loader = DataLoader(validation_dataset, batch_size=len(validation_dataset), shuffle=False)

# %%
# Attach model results to the race data using an sklearn model
def get_pytorch_model_results_for_races(df_validation: pd.DataFrame, feature_columns: list[str], model: nn.Module, target_column: str = 'model_prediction'):
    
    grouped = df_validation.groupby(['DateTime', 'Track Name'])

    races = []

    for (dt, track), group_df in grouped:

        race = group_df

        X_race = race[feature_columns].astype(np.float32)
        X_race = np.array(scaler.transform(X_race))

        X_race = torch.tensor(X_race)

        race[target_column] = torch.softmax(model(X_race), dim=0).detach()

        races.append(race)

    return races

# %%
import torch
import torch.nn as nn
import torch.optim as optim

classification_model = LogisticRegression(X_validation.shape[1])

num_epochs = 100

criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(classification_model.parameters(), lr=1e-4)

for epoch in range(num_epochs):

    epoch_loss = 0
    num_in_epoch = 0
    classification_model.train()
    for batch_x, batch_y in train_loader:
        # 1. Zero the parameter gradients
        optimizer.zero_grad()
        
        # 2. Forward pass
        outputs = classification_model(batch_x)
        
        # 3. Compute the loss (BCEWithLogitsLoss expects raw logits from the final layer)
        loss = criterion(outputs, torch.reshape(batch_y, (-1,1)))
        
        # 4. Backpropagation
        loss.backward()
        
        # 5. Update parameters
        optimizer.step()

        epoch_loss += loss.item()
        num_in_epoch += 1
    
    # Evaluation 
    classification_model.eval()
    race_results = get_pytorch_model_results_for_races(validation_data, feature_columns, classification_model)
    average_validation_log_loss = average_log_loss_score(race_results, 'model_prediction')

    # for batch_x, batch_y in validation_loader:
    #     # 2. Forward pass
    #     outputs = classification_model(batch_x)

    #     validation_loss = criterion(outputs, torch.reshape(batch_y, (-1,1)))

    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss/num_in_epoch:.4f}, Validation average log loss: {average_validation_log_loss:.4f}")

print("Training complete.")
# Out:
# Epoch 1/100, Loss: 0.5201, Validation average log loss: 2.0788
# Epoch 2/100, Loss: 0.3341, Validation average log loss: 1.9824
# Epoch 3/100, Loss: 0.3022, Validation average log loss: 1.9339
# Epoch 4/100, Loss: 0.2970, Validation average log loss: 1.9087
# Epoch 5/100, Loss: 0.2946, Validation average log loss: 1.8936
# Epoch 6/100, Loss: 0.2930, Validation average log loss: 1.8834
# Epoch 7/100, Loss: 0.2918, Validation average log loss: 1.8759
# Epoch 8/100, Loss: 0.2909, Validation average log loss: 1.8703
# Epoch 9/100, Loss: 0.2902, Validation average log loss: 1.8646
# Epoch 10/100, Loss: 0.2897, Validation average log loss: 1.8604
# Epoch 11/100, Loss: 0.2892, Validation average log loss: 1.8575
# Epoch 12/100, Loss: 0.2888, Validation average log loss: 1.8547
# Epoch 13/100, Loss: 0.2885, Validation average log loss: 1.8526
# Epoch 14/100, Loss: 0.2882, Validation average log loss: 1.8500
# Epoch 15/100, Loss: 0.2880, Validation average log loss: 1.8508
# Epoch 16/100, Loss: 0.2878, Validation average log loss: 1.8461
# Epoch 17/100, Loss: 0.2876, Validation average log loss: 1.8448
# Epoch 18/100, Loss: 0.2874, Validation average log loss: 1.8440
# Epoch 19/100, Loss: 0.2873, Validation average log loss: 1.8437
# Epoch 20/100, Loss: 0.2872, Validation average log loss: 1.8417
# Epoch 21/100, Loss: 0.2871, Validation average log loss: 1.8423
# Epoch 22/100, Loss: 0.2870, Validation average log loss: 1.8403
# Epoch 23/100, Loss: 0.2869, Validation average log loss: 1.8402
# Epoch 24/100, Loss: 0.2868, Validation average log loss: 1.8391
# Epoch 25/100, Loss: 0.2868, Validation average log loss: 1.8389
# Epoch 26/100, Loss: 0.2867, Validation average log loss: 1.8373
# Epoch 27/100, Loss: 0.2866, Validation average log loss: 1.8398
# Epoch 28/100, Loss: 0.2866, Validation average log loss: 1.8379
# Epoch 29/100, Loss: 0.2865, Validation average log loss: 1.8368
# Epoch 30/100, Loss: 0.2865, Validation average log loss: 1.8368
# Epoch 31/100, Loss: 0.2865, Validation average log loss: 1.8372
# Epoch 32/100, Loss: 0.2865, Validation average log loss: 1.8359
# Epoch 33/100, Loss: 0.2864, Validation average log loss: 1.8382
# Epoch 34/100, Loss: 0.2864, Validation average log loss: 1.8372
# Epoch 35/100, Loss: 0.2864, Validation average log loss: 1.8377
# Epoch 36/100, Loss: 0.2863, Validation average log loss: 1.8356
# Epoch 37/100, Loss: 0.2863, Validation average log loss: 1.8370
# Epoch 38/100, Loss: 0.2863, Validation average log loss: 1.8352
# Epoch 39/100, Loss: 0.2863, Validation average log loss: 1.8351
# Epoch 40/100, Loss: 0.2863, Validation average log loss: 1.8359
# Epoch 41/100, Loss: 0.2862, Validation average log loss: 1.8341
# Epoch 42/100, Loss: 0.2862, Validation average log loss: 1.8351
# Epoch 43/100, Loss: 0.2862, Validation average log loss: 1.8343
# Epoch 44/100, Loss: 0.2862, Validation average log loss: 1.8359
# Epoch 45/100, Loss: 0.2862, Validation average log loss: 1.8343
# Epoch 46/100, Loss: 0.2862, Validation average log loss: 1.8354
# Epoch 47/100, Loss: 0.2862, Validation average log loss: 1.8346
# Epoch 48/100, Loss: 0.2862, Validation average log loss: 1.8345
# Epoch 49/100, Loss: 0.2862, Validation average log loss: 1.8336
# Epoch 50/100, Loss: 0.2862, Validation average log loss: 1.8359
# Epoch 51/100, Loss: 0.2862, Validation average log loss: 1.8331
# Epoch 52/100, Loss: 0.2861, Validation average log loss: 1.8341
# Epoch 53/100, Loss: 0.2861, Validation average log loss: 1.8348
# Epoch 54/100, Loss: 0.2861, Validation average log loss: 1.8352
# Epoch 55/100, Loss: 0.2861, Validation average log loss: 1.8356
# Epoch 56/100, Loss: 0.2861, Validation average log loss: 1.8347
# Epoch 57/100, Loss: 0.2861, Validation average log loss: 1.8354
# Epoch 58/100, Loss: 0.2861, Validation average log loss: 1.8341
# Epoch 59/100, Loss: 0.2861, Validation average log loss: 1.8340
# Epoch 60/100, Loss: 0.2861, Validation average log loss: 1.8345
# Epoch 61/100, Loss: 0.2861, Validation average log loss: 1.8329
# Epoch 62/100, Loss: 0.2861, Validation average log loss: 1.8334
# Epoch 63/100, Loss: 0.2861, Validation average log loss: 1.8351
# Epoch 64/100, Loss: 0.2861, Validation average log loss: 1.8328
# Epoch 65/100, Loss: 0.2861, Validation average log loss: 1.8321
# Epoch 66/100, Loss: 0.2860, Validation average log loss: 1.8350
# Epoch 67/100, Loss: 0.2860, Validation average log loss: 1.8340
# Epoch 68/100, Loss: 0.2860, Validation average log loss: 1.8372
# Epoch 69/100, Loss: 0.2861, Validation average log loss: 1.8349
# Epoch 70/100, Loss: 0.2860, Validation average log loss: 1.8351
# Epoch 71/100, Loss: 0.2860, Validation average log loss: 1.8366
# Epoch 72/100, Loss: 0.2860, Validation average log loss: 1.8340
# Epoch 73/100, Loss: 0.2860, Validation average log loss: 1.8342
# Epoch 74/100, Loss: 0.2860, Validation average log loss: 1.8340
# Epoch 75/100, Loss: 0.2860, Validation average log loss: 1.8332
# Epoch 76/100, Loss: 0.2860, Validation average log loss: 1.8324
# Epoch 77/100, Loss: 0.2860, Validation average log loss: 1.8342
# Epoch 78/100, Loss: 0.2860, Validation average log loss: 1.8338
# Epoch 79/100, Loss: 0.2860, Validation average log loss: 1.8360
# Epoch 80/100, Loss: 0.2860, Validation average log loss: 1.8325
# Epoch 81/100, Loss: 0.2860, Validation average log loss: 1.8346
# Epoch 82/100, Loss: 0.2860, Validation average log loss: 1.8329
# Epoch 83/100, Loss: 0.2860, Validation average log loss: 1.8343
# Epoch 84/100, Loss: 0.2860, Validation average log loss: 1.8335
# Epoch 85/100, Loss: 0.2860, Validation average log loss: 1.8342
# Epoch 86/100, Loss: 0.2860, Validation average log loss: 1.8339
# Epoch 87/100, Loss: 0.2860, Validation average log loss: 1.8334
# Epoch 88/100, Loss: 0.2860, Validation average log loss: 1.8340
# Epoch 89/100, Loss: 0.2860, Validation average log loss: 1.8336
# Epoch 90/100, Loss: 0.2860, Validation average log loss: 1.8350
# Epoch 91/100, Loss: 0.2860, Validation average log loss: 1.8337
# Epoch 92/100, Loss: 0.2860, Validation average log loss: 1.8333
# Epoch 93/100, Loss: 0.2859, Validation average log loss: 1.8328
# Epoch 94/100, Loss: 0.2860, Validation average log loss: 1.8342
# Epoch 95/100, Loss: 0.2859, Validation average log loss: 1.8329
# Epoch 96/100, Loss: 0.2859, Validation average log loss: 1.8338
# Epoch 97/100, Loss: 0.2859, Validation average log loss: 1.8328
# Epoch 98/100, Loss: 0.2859, Validation average log loss: 1.8354
# Epoch 99/100, Loss: 0.2859, Validation average log loss: 1.8344
# Epoch 100/100, Loss: 0.2859, Validation average log loss: 1.8339
# Training complete.

# %%
race_results = get_pytorch_model_results_for_races(validation_data, feature_columns, classification_model)
average_log_loss_score(race_results, 'model_prediction')

# %%
average_log_loss_score(race_results, 'model_prediction')
# Out:
# 1.819487061818238
